# %% [markdown]
# <a href="https://colab.research.google.com/github/krackalackel02/CS-M148/blob/main/M148_lab_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Google Colab, Python, and Data Exploration
#
# In this notebook, we will walk through the following topics:
# 1. Basic usage of Google Colab for running Python code.
# 2. Installing and using Python packages within a Colab environment.
# 3. Basic Python syntax and operations.
# 4. Exploring and analyzing data using popular packages like `pandas` and `seaborn`.
#
# This notebook is designed for students to familiarize themselves with the Google Colab interface, understand how to install and use Python packages, and learn to handle data using Python libraries.

# %% [markdown]
# ## Basic Usage of Google Colab
#
# Google Colab is a cloud-based Jupyter notebook environment that allows you to run Python code without needing to install anything on your local machine.
#
# ### Key Features:
# - Run Python code on a hosted environment.
# - Install and use Python packages dynamically.
# - Import and work with data files directly from Google Drive.
#
# In this section, we will go over some basic setup and package installation commands.

# %% [markdown]
# ## Jupyter and Colab Notebooks
# Before we dive into Python, we’d like to briefly talk about notebooks. A Jupyter notebook lets you write and execute Python code locally in your web browser. Jupyter notebooks make it very easy to tinker with code and execute it in bits and pieces; for this reason they are widely used in scientific computing. Colab on the other hand is Google’s flavor of Jupyter notebooks that is particularly suited for machine learning and data analysis and that runs entirely in the cloud. Colab is basically Jupyter notebook on steroids: it’s free, requires no setup, comes preinstalled with many packages, is easy to share with the world, and benefits from free access to hardware accelerators like GPUs and TPUs (with some caveats).

# %% [markdown]
# - Although usually people recommend that you setup on Colab, I recommend you to do it locally
# - This is because these notebooks are lightweight, and it's helpful to have experience setting up Conda and Jupyter
#
#
# If you prefer to use Colab, you can refer to [this documentation](https://colab.research.google.com/).

# %% [markdown]
# ### Anaconda
# The best way to setup your local development environment is to use [anaconda](https://www.anaconda.com/download). Depending on your Operating System, you should set it up either by `.exe` (on Windows), `.sh` (on Linux), or `.dmg` (on Mac). Once you finish the installation process, instead of using its Graphical User Interface, It is __better to launch it in the terminal__.
# - See here for easy setup of Anaconda, [link](https://docs.conda.io/projects/conda/en/latest/user-guide/install/index.html)
# - See here for a sheet of common conda commands, [link](https://docs.conda.io/projects/conda/en/4.6.0/_downloads/52a95608c49671267e40c689e0bc00ca/conda-cheatsheet.pdf), some notable ones:
#     - `conda create --name <env_name> python=3.10 numpy pandas scipy scikit-learn seaborn`: this one pretty much sets up your default environment, where `env_name` is a variable you set up, such as "CS148".
#     - After creating the environment, you can use the command `conda activate <env_name>` to activate this environment.
#
# The conda environment manages all your packages, so in your environment, if you want to use any new packages, you can use the command `conda install <package_name>` to do so. In vanilla python, this is handled by `pip install <package_name>`.
# - __It is a good idea to stick to only one of these two!__
# - usually avoid using `pip` unless you absolutely have to, such as when in the jupyter cell

# %%
# example of using pip in Jupyter
# use an excalamation mark before
# !pip install numpy

# %% [markdown]
# ### Jupyter
#
# After activating your conda environment, The `jupyter notebook` or `jupyter-lab` command from your terminal should launch the browser with the current directory as the root and you will see the notebooks in your default browser.
#
# Comparing Jupyter notebook with the standard Python Development environment:
# - Jupyter is easier to present to others your work, and can be easier to debug because of the fragmented snippets
# - Python scripts by itself is usually better in production, after you have tested your idea in the notebooks.
#
# __Warning: with the jupyter notebook, it is crucial to understand the scope of your initialized variables!__ This is because Jupyter is just a fancy version of your standard Python IDE, check what it means when I say [scope of variables](https://matthew-brett.github.io/teaching/global_scope.html).
#
# Jupyter has two types of cells:
# - markdown cells, where you can type markdown text. You can create one by creating a new cell then `Esc-M`.
# - python cells, which is by default when you create a new cell.
# - use the `Shift-Enter` key to run a cell

# %% [markdown]
# ## Basic Python Syntax and Data Types
#
# Before we dive into working with data, let's go over some basic Python syntax:
# - Variables and data types
# - Loops and conditionals
# - Functions and modules
#
# We will cover examples that will help you get comfortable with Python coding.

# %% [markdown]
# Python is a high-level, dynamically typed multiparadigm programming language. Python code is often said to be almost like pseudocode, since it allows you to express very powerful ideas in very few lines of code while being very readable. As an example, here is an implementation of the classic quicksort algorithm in Python:

# %%
def quicksort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quicksort(left) + middle + quicksort(right)

print(quicksort([3,6,8,10,1,2,1]))
# Out:
# [1, 1, 2, 3, 6, 8, 10]

# %% [markdown]
# ### Basic Data Types

# %%
# numeric data types
x = 3
print(type(x)) # Prints "<class 'int'>"
print(x)       # Prints "3"
print(x + 1)   # Addition; prints "4"
print(x - 1)   # Subtraction; prints "2"
print(x * 2)   # Multiplication; prints "6"
print(x ** 2)  # Exponentiation; prints "9"
x += 1
print(x)  # Prints "4"
x *= 2
print(x)  # Prints "8"
y = 2.5
print(type(y)) # Prints "<class 'float'>"
print(y, y + 1, y * 2, y ** 2) # Prints "2.5 3.5 5.0 6.25"
# Out:
# <class 'int'>
# 3
# 4
# 2
# 6
# 9
# 4
# 8
# <class 'float'>
# 2.5 3.5 5.0 6.25

# %%
# Boolean
t = True
f = False
print(type(t)) # Prints "<class 'bool'>"
print(t and f) # Logical AND; prints "False"
print(t or f)  # Logical OR; prints "True"
print(not t)   # Logical NOT; prints "False"
print(t != f)  # Logical XOR; prints "True"
# Out:
# <class 'bool'>
# False
# True
# False
# True

# %%
# string
hello = 'hello'    # String literals can use single quotes
world = "world"    # or double quotes; it does not matter.
print(hello)       # Prints "hello"
print(len(hello))  # String length; prints "5"
hw = hello + ' ' + world  # String concatenation
print(hw)  # prints "hello world"
hw12 = '%s %s %d' % (hello, world, 12)  # sprintf style string formatting
print(hw12)  # prints "hello world 12"
# Out:
# hello
# 5
# hello world
# hello world 12

# %%
# string manipulations
s = "hello"
print(s.capitalize())  # Capitalize a string; prints "Hello"
print(s.upper())       # Convert a string to uppercase; prints "HELLO"
print(s.rjust(7))      # Right-justify a string, padding with spaces; prints "  hello"
print(s.center(7))     # Center a string, padding with spaces; prints " hello "
print(s.replace('l', '(ell)'))  # Replace all instances of one substring with another;
                                # prints "he(ell)(ell)o"
print('  world '.strip())  # Strip leading and trailing whitespace; prints "world"
# Out:
# Hello
# HELLO
#   hello
#  hello
# he(ell)(ell)o
# world

# %% [markdown]
# ### List
#
# A list is the Python equivalent of an array, but is resizeable and can contain elements of different types:

# %%
xs = [3, 1, 2]    # Create a list
print(xs, xs[2])  # Prints "[3, 1, 2] 2"
print(xs[-1])     # Negative indices count from the end of the list; prints "2"
xs[2] = 'foo'     # Lists can contain elements of different types
print(xs)         # Prints "[3, 1, 'foo']"
xs.append('bar')  # Add a new element to the end of the list
print(xs)         # Prints "[3, 1, 'foo', 'bar']"
x = xs.pop()      # Remove and return the last element of the list
print(x, xs)      # Prints "bar [3, 1, 'foo']"
# Out:
# [3, 1, 2] 2
# 2
# [3, 1, 'foo']
# [3, 1, 'foo', 'bar']
# bar [3, 1, 'foo']

# %%
# slicing
nums = list(range(5))     # range is a built-in function that creates a list of integers
print(nums)               # Prints "[0, 1, 2, 3, 4]"
print(nums[2:4])          # Get a slice from index 2 to 4 (exclusive); prints "[2, 3]"
print(nums[2:])           # Get a slice from index 2 to the end; prints "[2, 3, 4]"
print(nums[:2])           # Get a slice from the start to index 2 (exclusive); prints "[0, 1]"
print(nums[:])            # Get a slice of the whole list; prints "[0, 1, 2, 3, 4]"
print(nums[:-1])          # Slice indices can be negative; prints "[0, 1, 2, 3]"
nums[2:4] = [8, 9]        # Assign a new sublist to a slice
print(nums)               # Prints "[0, 1, 8, 9, 4]"
# Out:
# [0, 1, 2, 3, 4]
# [2, 3]
# [2, 3, 4]
# [0, 1]
# [0, 1, 2, 3, 4]
# [0, 1, 2, 3]
# [0, 1, 8, 9, 4]

# %%
# loop
animals = ['cat', 'dog', 'monkey']
for animal in animals:
    print(animal)
# Out:
# cat
# dog
# monkey

# %%
# loop
animals = ['cat', 'dog', 'monkey']
for idx, animal in enumerate(animals):
    print('#%d: %s' % (idx + 1, animal))
# Out:
# #1: cat
# #2: dog
# #3: monkey

# %%
# list comprehension
nums = [0, 1, 2, 3, 4]
squares = [x ** 2 for x in nums]
print(squares)   # Prints [0, 1, 4, 9, 16]
# Out:
# [0, 1, 4, 9, 16]

# %%
nums = [0, 1, 2, 3, 4]
even_squares = [x ** 2 for x in nums if x % 2 == 0]
print(even_squares)  # Prints "[0, 4, 16]"
# Out:
# [0, 4, 16]

# %% [markdown]
# ### Dictionary

# %%
d = {'cat': 'cute', 'dog': 'furry'}  # Create a new dictionary with some data
print(d['cat'])       # Get an entry from a dictionary; prints "cute"
print('cat' in d)     # Check if a dictionary has a given key; prints "True"
d['fish'] = 'wet'     # Set an entry in a dictionary
print(d['fish'])      # Prints "wet"
# print(d['monkey'])  # KeyError: 'monkey' not a key of d
print(d.get('monkey', 'N/A'))  # Get an element with a default; prints "N/A"
print(d.get('fish', 'N/A'))    # Get an element with a default; prints "wet"
del d['fish']         # Remove an element from a dictionary
print(d.get('fish', 'N/A')) # "fish" is no longer a key; prints "N/A"
# Out:
# cute
# True
# wet
# N/A
# wet
# N/A

# %%
d = {'person': 2, 'cat': 4, 'spider': 8}
for animal in d:
    legs = d[animal]
    print('A %s has %d legs' % (animal, legs))
# Prints "A person has 2 legs", "A cat has 4 legs", "A spider has 8 legs"
# Out:
# A person has 2 legs
# A cat has 4 legs
# A spider has 8 legs

# %%
d = {'person': 2, 'cat': 4, 'spider': 8}
for animal, legs in d.items():
    print('A %s has %d legs' % (animal, legs))
# Prints "A person has 2 legs", "A cat has 4 legs", "A spider has 8 legs"
# Out:
# A person has 2 legs
# A cat has 4 legs
# A spider has 8 legs

# %%
# dict comprehension
nums = [0, 1, 2, 3, 4]
even_num_to_square = {x: x ** 2 for x in nums if x % 2 == 0}
print(even_num_to_square)  # Prints "{0: 0, 2: 4, 4: 16}"
# Out:
# {0: 0, 2: 4, 4: 16}

# %% [markdown]
# ### Sets
# un-ordered and contains only unique items:

# %%
animals = {'cat', 'dog'}
print('cat' in animals)   # Check if an element is in a set; prints "True"
print('fish' in animals)  # prints "False"
animals.add('fish')       # Add an element to a set
print('fish' in animals)  # Prints "True"
print(len(animals))       # Number of elements in a set; prints "3"
animals.add('cat')        # Adding an element that is already in the set does nothing
print(len(animals))       # Prints "3"
animals.remove('cat')     # Remove an element from a set
print(len(animals))       # Prints "2"
# Out:
# True
# False
# True
# 3
# 3
# 2

# %%
animals = {'cat', 'dog', 'fish'}
for idx, animal in enumerate(animals):
    print('#%d: %s' % (idx + 1, animal))
# Prints "#1: fish", "#2: dog", "#3: cat"
# Out:
# #1: dog
# #2: cat
# #3: fish

# %%
from math import sqrt
nums = {int(sqrt(x)) for x in range(30)}
print(nums)  # Prints "{0, 1, 2, 3, 4, 5}"
# Out:
# {0, 1, 2, 3, 4, 5}

# %% [markdown]
# ### Tuples
# A tuple is an (immutable) ordered list of values. A tuple is in many ways similar to a list; one of the most important differences is that tuples can be used as keys in dictionaries and as elements of sets, while lists cannot. Here is a trivial example:

# %%
d = {(x, x + 1): x for x in range(10)}  # Create a dictionary with tuple keys
t = (5, 6)        # Create a tuple
print(type(t))    # Prints "<class 'tuple'>"
print(d[t])       # Prints "5"
print(d[(1, 2)])  # Prints "1"
# Out:
# <class 'tuple'>
# 5
# 1

# %% [markdown]
# ### Functions

# %%
# def keyword defines a unit of executable code with its own context


def sign(x):
    if x > 0:
        return 'positive'
    elif x < 0:
        return 'negative'
    else:
        return 'zero'

for x in [-1, 0, 1]:
    print(sign(x))
# Prints "negative", "zero", "positive"
# Out:
# negative
# zero
# positive

# %%
# example of optional argument
def hello(name, loud=False):
    if loud:
        print('HELLO, %s!' % name.upper())
    else:
        print('Hello, %s' % name)

hello('Bob') # Prints "Hello, Bob"
hello('Fred', loud=True)  # Prints "HELLO, FRED!"
# Out:
# Hello, Bob
# HELLO, FRED!

# %% [markdown]
# ### Class
# The core of Object-Oriented Programming

# %%
class Greeter(object):

    # Constructor
    def __init__(self, name):
        self.name = name  # Create an instance variable

    # Instance method
    def greet(self, loud=False):
        if loud:
            print('HELLO, %s!' % self.name.upper())
        else:
            print('Hello, %s' % self.name)

g = Greeter('Fred')  # Construct an instance of the Greeter class
g.greet()            # Call an instance method; prints "Hello, Fred"
g.greet(loud=True)   # Call an instance method; prints "HELLO, FRED!"
# Out:
# Hello, Fred
# HELLO, FRED!

# %% [markdown]
# ## Data Exploration with Pandas and Seaborn
#
# In this section, we will explore how to load and visualize data using `pandas` and `seaborn`. These are essential libraries for data manipulation and visualization in Python.
#
# - `pandas`: Used for data manipulation and analysis.
# - `seaborn`: A visualization library built on top of `matplotlib` that makes it easy to create informative plots.
#
# We will go over:
# - Loading data into a pandas DataFrame.
# - Inspecting and cleaning data.
# - Visualizing trends and distributions with seaborn.
#
# Let's get started with data exploration!

# %%
# import your necessary libraries
import pandas as pd
import numpy as np

# %% [markdown]
# We load the dataset into a pandas DataFrame. This allows us to manipulate the data easily.
#
# The dataset could be a CSV file or any structured data format.

# %%
data = {
    "Name": ["John", "Jane", "Mike"],
    "Age": [25, 30, 35],
    "City": ["New York", "London", "Paris"]
}
df = pd.DataFrame(data)
print(df.index)
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %% [markdown]
# This command gives a quick overview of the dataset's structure, showing column names, non-null counts, and data types.
#
# It helps us check for missing data and get a sense of the dataset's size.

# %%
df
# Out:
#    Name  Age      City
# 0  John   25  New York
# 1  Jane   30    London
# 2  Mike   35     Paris

# %%
# load from a file
# download the csv file from https://drive.google.com/file/d/1naXzDqvuaTv69244yD5n77nUVbKn4JCY/view?usp=sharing
# place the csv file in the colab workspace
df = pd.read_csv("/content/housing.csv")
df.shape
# Out:
# (20640, 10)

# %% [markdown]
# ### Taking a Sample of Data
# use the `DataFrame.sample` method

# %%
indices = np.random.choice(df.index, size=100, replace=False)
df_subset = df.loc[indices]

# %%
# another way
df_subset_1 = df.sample(100)

# %% [markdown]
# ### Applying Filters and Building Balanced Dataset

# %%
df.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
# use boolean conditions
condition1 = df["housing_median_age"] <= 30
condition2 = df["total_rooms"] >= 1000
df_filtered = df[condition1 & condition2]

# %%
df_filtered.head(5)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1     -122.22     37.86                21.0       7099.0          1106.0
# 75    -122.28     37.81                17.0       1237.0           462.0
# 77    -122.28     37.81                19.0       1207.0           243.0
# 78    -122.29     37.81                23.0       1745.0           374.0
# 93    -122.27     37.79                27.0       1055.0           347.0
#
#     population  households  median_income  median_house_value ocean_proximity
# 1       2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 75       762.0       439.0         0.9241            177500.0        NEAR BAY
# 77       721.0       207.0         1.1111            108300.0        NEAR BAY
# 78      1054.0       325.0         0.8026            112500.0        NEAR BAY
# 93       718.0       302.0         2.6354            187500.0        NEAR BAY

# %%
print(df.shape)
print(df_filtered.shape)
# Out:
# (20640, 10)
# (10222, 10)

# %%
# groups within a column
df_filtered["ocean_proximity"].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     4329
# INLAND        4025
# NEAR OCEAN    1288
# NEAR BAY       579
# ISLAND           1
# Name: count, dtype: int64

# %%
toy_data = {
    "workclass": ["Private", "Self-emp", "Private", "Self-emp", "Private"],
    "sex_selfID": ["Male", "Female", None, "Male", "Female"],
    "age": [25,30,35,40,45]
}

# %%
df = pd.DataFrame(toy_data)

# %%
df
# Out:
#   workclass sex_selfID  age
# 0   Private       Male   25
# 1  Self-emp     Female   30
# 2   Private       None   35
# 3  Self-emp       Male   40
# 4   Private     Female   45

# %%
df_filter = df[(df["workclass"]=="Private") & ~(df["sex_selfID"].isnull())]

# %%
df_filter
# Out:
#   workclass sex_selfID  age
# 0   Private       Male   25
# 4   Private     Female   45

# %%
df["sex_selfID"].value_counts()
# Out:
# sex_selfID
# Male      2
# Female    2
# Name: count, dtype: int64

# %%
toy_data = {"sex_selfID": ["Male","Female","Female","Female","Male","Female","Male"],
           "label": ["A","B","A","A","B","B","A"]}
df = pd.DataFrame(toy_data)
df.groupby(["sex_selfID", "label"]).size()
# Out:
# sex_selfID  label
# Female      A        2
#             B        2
# Male        A        2
#             B        1
# dtype: int64

# %%
# modifying / merging labels
toy_data = {"workclass": ['Private', 'Self-emp', None, 'Private', 'Self-emp'],
           'age': [25,30,35,40,45]}
df = pd.DataFrame(toy_data)
columns_not_self_employed = df["workclass"] != "Self-emp"
columns_not_null = df["workclass"].notnull()

# %%
df
# Out:
#   workclass  age
# 0   Private   25
# 1  Self-emp   30
# 2      None   35
# 3   Private   40
# 4  Self-emp   45

# %%
columns_not_self_employed
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# Name: workclass, dtype: bool

# %%
columns_not_null
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# Name: workclass, dtype: bool

# %%
condition = columns_not_self_employed & columns_not_null

# %%
#  this is saying
# for the column workclass
# if the entry is not null and it is not "Self-emp"
# modify this entry to "Not-self-emp"
df["workclass"] = np.where(condition, "Not-self-emp", df["workclass"])

# %%
df
# Out:
#       workclass  age
# 0  Not-self-emp   25
# 1      Self-emp   30
# 2          None   35
# 3  Not-self-emp   40
# 4      Self-emp   45

# %% [markdown]
# ### Create Labels and Features: Clean and Convert Data

# %%
# convert a column to type int
df_house = pd.read_csv("housing.csv")
df_house.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df_house["population"] = df_house["population"].astype(int)
df_house.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322       126.0         8.3252            452600.0        NEAR BAY
# 1        2401      1138.0         8.3014            358500.0        NEAR BAY
# 2         496       177.0         7.2574            352100.0        NEAR BAY
# 3         558       219.0         5.6431            341300.0        NEAR BAY
# 4         565       259.0         3.8462            342200.0        NEAR BAY

# %%
df_subset = df_house.sample(100)

# %%
# create new sample that doesn't include original sample
df_never_sampled = df_house.drop(labels=df_subset.index, axis=0, inplace=False)

# %%
df_never_sampled.shape
# Out:
# (20540, 10)

# %%
df_house.shape
# Out:
# (20640, 10)

# %%
df_house = df_house.drop(["longitude", "latitude"], axis=1)
df_house.head(5)
# Out:
#    housing_median_age  total_rooms  total_bedrooms  population  households  \
# 0                41.0        880.0           129.0         322       126.0
# 1                21.0       7099.0          1106.0        2401      1138.0
# 2                52.0       1467.0           190.0         496       177.0
# 3                52.0       1274.0           235.0         558       219.0
# 4                52.0       1627.0           280.0         565       259.0
#
#    median_income  median_house_value ocean_proximity
# 0         8.3252            452600.0        NEAR BAY
# 1         8.3014            358500.0        NEAR BAY
# 2         7.2574            352100.0        NEAR BAY
# 3         5.6431            341300.0        NEAR BAY
# 4         3.8462            342200.0        NEAR BAY

# %% [markdown]
# ### Order and Categorical Data

# %%
df_house = pd.read_csv("housing.csv")
df_house.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df_house["ocean_proximity"].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
# on the housing dataset
proximity_order = ["ISLAND", "NEAR OCEAN", "NEAR BAY", "<1H OCEAN", "INLAND"]
df_house["ocean_proximity"] = pd.Categorical(df_house["ocean_proximity"], ordered=True, categories=proximity_order)
df_house.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df_house = df_house.sort_values('ocean_proximity').reset_index(drop=True)
df_house.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -118.48     33.43                29.0        716.0           214.0
# 1    -118.32     33.34                52.0        996.0           264.0
# 2    -118.32     33.33                52.0       2127.0           512.0
# 3    -118.33     33.34                52.0       2359.0           591.0
# 4    -118.32     33.35                27.0       1675.0           521.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       422.0       173.0         2.6042            287500.0          ISLAND
# 1       341.0       160.0         2.7361            450000.0          ISLAND
# 2       733.0       288.0         3.3906            300000.0          ISLAND
# 3      1100.0       431.0         2.8333            414700.0          ISLAND
# 4       744.0       331.0         2.1579            450000.0          ISLAND

# %% [markdown]
# ### One-hot Encoding

# %%
df_binary = pd.get_dummies(df_house)
df_binary.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -118.48     33.43                29.0        716.0           214.0
# 1    -118.32     33.34                52.0        996.0           264.0
# 2    -118.32     33.33                52.0       2127.0           512.0
# 3    -118.33     33.34                52.0       2359.0           591.0
# 4    -118.32     33.35                27.0       1675.0           521.0
# 5    -117.35     33.21                18.0       2971.0           606.0
# 6    -117.38     33.21                31.0       1502.0           367.0
# 7    -117.37     33.20                29.0       1315.0           311.0
# 8    -117.34     33.23                11.0       3737.0           757.0
# 9    -117.33     33.23                15.0       2919.0           592.0
#
#    population  households  median_income  median_house_value  \
# 0       422.0       173.0         2.6042            287500.0
# ...

# %% [markdown]
# ### Simple Data Exploration

# %%
df_summ = df_house.describe()
df_summ
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df_summ.shape
# Out:
# (8, 9)

# %%
df_summ.loc["std"].idxmax()
# Out:
# 'median_house_value'

# %%
df_summ.idxmax(axis=1)["std"]
# Out:
# 'median_house_value'

# %%
np.any(df_summ.loc["min"] < 0)
# Out:
# True

# %% [markdown]
# ### Simple Visualization

# %%
# simple visualization
# !pip install seaborn
import seaborn as sns

# %%
sns.histplot(data=df_subset, x="total_rooms")
# Out:
# <Axes: xlabel='total_rooms', ylabel='Count'>

# %%
sns.pairplot(data=df_subset, hue="ocean_proximity")

# %%
sns.pairplot(data=df_subset, kind='kde', corner=True) # kde density estimator type plot

# %%
# can set fiture size beforehand
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,8))
sns.histplot(data=df_subset, x="total_rooms")
# Out:
# <Axes: xlabel='total_rooms', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
plt.ylim(10,25)
plt.xticks(rotation=45)
sns.histplot(data=df_subset, x="total_rooms")
# Out:
# <Axes: xlabel='total_rooms', ylabel='Count'>

# %%
df_house.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %% [markdown]
# ### Correlation

# %%
# Convert the 'ocean_proximity' column to numerical data using one-hot encoding
df_subset = pd.get_dummies(df_subset, columns=['ocean_proximity'], drop_first=True)
# drop_first=True is used to prevent multicollinearity
# Now calculate the correlation
df_subset.corr()
# Out:
#                             longitude  latitude  housing_median_age  \
# longitude                    1.000000 -0.927408           -0.102932
# latitude                    -0.927408  1.000000            0.033884
# housing_median_age          -0.102932  0.033884            1.000000
# total_rooms                  0.181204 -0.150389           -0.243904
# total_bedrooms               0.134105 -0.120294           -0.172610
# population                   0.193570 -0.161521           -0.170409
# households                   0.128270 -0.116126           -0.150738
# median_income                0.171723 -0.302920           -0.087807
# median_house_value           0.002551 -0.207452            0.108727
# ocean_proximity_INLAND      -0.040155  0.320431           -0.082423
# ocean_proximity_NEAR BAY    -0.425318  0.300182            0.235457
# ocean_proximity_NEAR OCEAN   0.085645 -0.187613            0.036169
#
#                             total_rooms  total_bedrooms  population  \
# ...

# %%
df_subset.corr()["median_house_value"].drop(["median_house_value"], axis=0)
# Out:
# longitude                     0.002551
# latitude                     -0.207452
# housing_median_age            0.108727
# total_rooms                   0.186367
# total_bedrooms                0.165402
# population                    0.045277
# households                    0.179779
# median_income                 0.753532
# ocean_proximity_INLAND       -0.552291
# ocean_proximity_NEAR BAY      0.212592
# ocean_proximity_NEAR OCEAN    0.156458
# Name: median_house_value, dtype: float64

# %%
corrs_sorted = df_subset.corr()["median_house_value"].drop(["median_house_value"], axis=0).sort_values(ascending=False)
corrs_sorted
# Out:
# median_income                 0.753532
# ocean_proximity_NEAR BAY      0.212592
# total_rooms                   0.186367
# households                    0.179779
# total_bedrooms                0.165402
# ocean_proximity_NEAR OCEAN    0.156458
# housing_median_age            0.108727
# population                    0.045277
# longitude                     0.002551
# latitude                     -0.207452
# ocean_proximity_INLAND       -0.552291
# Name: median_house_value, dtype: float64

# %%
col_names = corrs_sorted.index

# %%
col_names
# Out:
# Index(['median_income', 'ocean_proximity_NEAR BAY', 'total_rooms',
#        'households', 'total_bedrooms', 'ocean_proximity_NEAR OCEAN',
#        'housing_median_age', 'population', 'longitude', 'latitude',
#        'ocean_proximity_INLAND'],
#       dtype='object')

# %% [markdown]
# ### Outliers

# %%
val = np.percentile(df_house["median_house_value"], 99) # top 1 percentile

# %%
val
# Out:
# 500001.0

# %%
import scipy.stats as stats
# replace lower and top 1% with values at 1% and 99% respectively
df_house["median_house_value"] = stats.mstats.winsorize(df_house["median_house_value"], limits=[0.01,0.01])

# %%
# zscore
zscores = stats.zscore(df_house["median_house_value"])

# %%
zscores
# Out:
# 0        0.698864
# 1        2.108269
# 2        0.807280
# 3        1.802103
# 4        2.108269
#            ...
# 20635   -1.144204
# 20636   -1.019309
# 20637   -1.209254
# 20638   -1.059206
# 20639   -1.019309
# Name: median_house_value, Length: 20640, dtype: float64

# %%
# replace missing values
df_house.isnull()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 20635      False     False               False        False           False
# 20636      False     False               False        False           False
# 20637      False     False               False        False           False
# 20638      False     False               False        False           False
# 20639      False     False               False        False           False
#
# ...

# %%
df_house.isnull().any()
# Out:
# longitude             False
# latitude              False
# housing_median_age    False
# total_rooms           False
# total_bedrooms         True
# population            False
# households            False
# median_income         False
# median_house_value    False
# ocean_proximity       False
# dtype: bool

# %%
nan_count = np.sum(df_house.isnull())
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
nan_count
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
mean_bedrooms=df_house['total_bedrooms'].mean()
df_house['total_bedrooms'].fillna(value=mean_bedrooms, inplace=True)

# %%
nan_count = np.sum(df_house.isnull())
nan_count
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64
